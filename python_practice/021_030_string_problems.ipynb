# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 03. 파이썬 문자열 (021 ~ 030)

# %% [markdown]
# ### 021 문자열 인덱싱

# %% [markdown]
# letters가 바인딩하는 문자열에서 첫번째와 세번째 문자를 출력하세요.
# ```python
# letters = 'python'
# ```
# ```
# 실행 예:
# p t
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 파이썬 문자열에서 한 글자를 가져오는 것을 인덱싱이라고 부릅니다. 파이썬 인덱싱은 0부터 시작합니다.</br>
# <pre>
# letters = 'python'
# print(letters[0], letters[2])
# </pre>
# </details>

# %%
letters = 'python'
# 여기에 코드를 작성하세요
print(letters[0], letters[2])
# Out:
# p t

# %% [markdown]
# ### 022 문자열 슬라이싱

# %% [markdown]
# 자동차 번호가 다음과 같을 때 뒤에 4자리만 출력하세요.
# ```python
# license_plate = "24가 2210"
# ```
# ```
# 실행 예: 2210
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 문자열에서 여러 글자를 가져오는 것을 슬라이싱이라고 부릅니다. 음수 값은 뒤에서부터 인덱싱/슬라이싱함을 의미합니다.</br>
# <pre>
# license_plate = "24가 2210"
# print(license_plate[-4:])
# </pre>
# </details>

# %%
license_plate = "24가 2210"
# 여기에 코드를 작성하세요
print (license_plate[-4:])
# Out:
# 2210

# %% [markdown]
# ### 023 문자열 인덱싱

# %% [markdown]
# 아래의 문자열에서 '홀' 만 출력하세요.
# ```python
# string = "홀짝홀짝홀짝"
# ```
# ```
# 실행 예:
# 홀홀홀
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 슬라이싱할 때 <code>시작인덱스:끝인덱스:오프셋</code>을 지정할 수 있습니다. 오프셋을 2로 지정하면 두 칸씩 건너뛰며 가져옵니다.</br>
# <pre>
# string = "홀짝홀짝홀짝"
# print(string[::2])
# </pre>
# </details>

# %%
string = "홀짝홀짝홀짝"
# 여기에 코드를 작성하세요
for i in range (0, len(string)):
    if not (i % 2): 
        print(string[i], end='')
## 파이썬의 print 는 기본적으로 각 출력 뒤에 \n 를 붙인다.
## 이를 없애고 싶으면 end=''를 추가한다.

# 파이썬의 인덱싱 사용
print()
print(string[::2])
# Out:
# 홀홀홀
# 홀홀홀

# %% [markdown]
# ### 024 문자열 슬라이싱

# %% [markdown]
# 문자열을 거꾸로 뒤집어 출력하세요.
# ```python
# string = "PYTHON"
# ```
# ```
# 실행 예:
# NOHTYP
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 슬라이싱에서 오프셋을 -1로 지정하면 문자열을 거꾸로 뒤집을 수 있습니다.</br>
# <pre>
# string = "PYTHON"
# print(string[::-1])
# </pre>
# </details>

# %%
string = "PYTHON"
# 여기에 코드를 작성하세요
print(string[::-1])
# Out:
# NOHTYP

# %% [markdown]
# ### 025 문자열 치환

# %% [markdown]
# 아래의 전화번호에서 하이픈('-')을 제거하고 공백으로 바꿔 출력하세요.
# ```python
# phone_number = "010-1111-2222"
# ```
# ```
# 실행 예:
# 010 1111 2222
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# replace 메서드를 사용하면 문자열 일부를 다른 문자열로 치환할 수 있습니다.</br>
# <pre>
# phone_number = "010-1111-2222"
# phone_number1 = phone_number.replace("-", " ")
# print(phone_number1)
# </pre>
# </details>

# %%
phone_number = "010-1111-2222"
# 여기에 코드를 작성하세요
print(phone_number.replace('-', ' '))

## 원본 문자열을 바꾸지 말고 새로운 문자열을 만들어서 하는 방법이 안전하다.
phon_number_new = phone_number.replace('-', ' ')
print(phon_number_new)
# Out:
# 010 1111 2222
# 010 1111 2222

# %% [markdown]
# ### 026 문자열 다루기

# %% [markdown]
# 025번 전화번호를 아래와 같이 하이픈 없이 모두 붙여 출력하세요.
# ```python
# phone_number = "010-1111-2222"
# ```
# ```
# 실행 예:
# 01011112222
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# replace에서 두 번째 인자를 빈 문자열('')로 지정하면 해당 문자를 완전히 제거합니다.</br>
# <pre>
# phone_number = "010-1111-2222"
# phone_number1 = phone_number.replace('-', '')
# print(phone_number1)
# </pre>
# </details>

# %%
phone_number = "010-1111-2222"
# 여기에 코드를 작성하세요
phone_number_new = phone_number.replace('-', '')

print(phone_number_new)
# Out:
# 01011112222

# %% [markdown]
# ### 027 문자열 다루기

# %% [markdown]
# url에 저장된 웹 페이지 주소에서 도메인을 출력하세요.
# ```python
# url = "http://sharebook.kr"
# ```
# ```
# 실행 예:
# kr
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# split() 메서드는 특정 문자를 기준으로 문자열을 나눠 리스트로 반환합니다. 마지막 요소를 인덱싱하면 도메인만 얻을 수 있습니다.</br>
# <pre>
# url = "http://sharebook.kr"
# url_split = url.split('.')
# print(url_split[-1])
# </pre>
# </details>

# %%
url = "http://sharebook.kr"
# 여기에 코드를 작성하세요
url_domain = url[-2:]

print(url_domain)

## domain 기준으로 나눌거니까 split 메서드 사용해서 특정 문자를 기준으로 문자열을 나눠보자

url_domain_1 = url.split('.')
print(url_domain_1[-1])
# Out:
# kr
# kr

# %% [markdown]
# ### 028 문자열은 immutable

# %% [markdown]
# 아래 코드의 실행 결과를 예상해보세요.
# ```python
# lang = 'python'
# lang[0] = 'P'
# print(lang)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 문자열은 수정할 수 없는(immutable) 자료형입니다. 인덱싱으로 값을 바꾸려 하면 TypeError가 발생합니다.</br>
# <pre>
# # 실행 결과:
# # TypeError: 'str' object does not support item assignment
# lang = 'python'
# lang[0] = 'P'  # 오류 발생!
# print(lang)
# </pre>
# </details>

# %%
# 직접 실행해서 어떤 오류가 나는지 확인해보세요
lang = 'python'
lang[0] = 'P'
print(lang)

## 문자열은 인덱싱으로 바꿀 수 없다. type error 발생
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 # 직접 실행해서 어떤 오류가 나는지 확인해보세요
#       2 lang = 'python'
# ----> 3 lang[0] = 'P'
#       4 print(lang)
#       6 ## 문자열은 인덱싱으로 바꿀 수 없다. type error 발생
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### 029 replace 메서드

# %% [markdown]
# 아래 문자열에서 소문자 'a'를 대문자 'A'로 변경하세요.
# ```python
# string = 'abcdfe2a354a32a'
# ```
# ```
# 실행 예:
# Abcdfe2A354A32A
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# replace 메서드는 해당 문자열 내 모든 대상을 한 번에 치환합니다.</br>
# <pre>
# string = 'abcdfe2a354a32a'
# string = string.replace('a', 'A')
# print(string)
# </pre>
# </details>

# %%
string = 'abcdfe2a354a32a'
# 여기에 코드를 작성하세요
string_up = string.replace('a', 'A')
print(string_up)
# Out:
# Abcdfe2A354A32A

# %% [markdown]
# ### 030 replace 메서드

# %% [markdown]
# 아래 코드의 실행 결과를 예상해보세요.
# ```python
# string = 'abcd'
# string.replace('b', 'B')
# print(string)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>abcd</code>가 그대로 출력됩니다. 문자열은 변경할 수 없는 자료형이므로 replace 메서드는 원본을 그대로 두고 변경된 새로운 문자열을 리턴합니다. 반환값을 변수에 저장해야 사용할 수 있습니다.</br>
# <pre>
# string = 'abcd'
# string.replace('b', 'B')  # 반환값을 저장하지 않음
# print(string)  # abcd (원본 그대로)
#
# # 올바른 방법:
# string = string.replace('b', 'B')
# print(string)  # aBcd
# </pre>
# </details>

# %%
# 직접 실행해서 결과를 확인해보세요
string = 'abcd'
string.replace('b', 'B')
print(string)


## abcd
# Out:
# abcd
